# %%
students=['Anil','Simran','Sreeja','Keerthi','Rafi','Salini']

# %%
print(students)
# Out:
# ['Anil', 'Simran', 'Sreeja', 'Keerthi', 'Rafi', 'Salini']

# %%
type(students)
# Out:
# list

# %%
#req: I want to access simran from the above list...?

# %%
print(students[1])
# Out:
# Simran

# %%
#req: I want to access keerthi name from the above list..?

# %%
print(students[3])
# Out:
# Keerthi

# %%
print(students)
# Out:
# ['Anil', 'Simran', 'Sreeja', 'Keerthi', 'Rafi', 'Salini']

# %%
#req: I want to add naveen to the above list?

# %%
students.append('Naveen')
print(students)
# Out:
# ['Anil', 'Simran', 'Sreeja', 'Keerthi', 'Rafi', 'Salini', 'Naveen']

# %%
#req: I want to add adil to the abpve list..?

# %%
students.append('Adil')
print(students)
# Out:
# ['Anil', 'Simran', 'Sreeja', 'Keerthi', 'Rafi', 'Salini', 'Adil']

# %%
# req: I want to add pallavi to the second index?

# %%
students.insert(2,'Pallavi')
print(students)
# Out:
# ['Anil', 'Simran', 'Pallavi', 'Sreeja', 'Keerthi', 'Rafi', 'Salini', 'Adil']

# %%
print(students[2])
# Out:
# Pallavi

# %%
print(students)
# Out:
# ['Anil', 'Simran', 'Pallavi', 'Sreeja', 'Keerthi', 'Rafi', 'Salini', 'Adil']

# %%
#req: I want to change Sreeja name to Meghana...?

# %%
print(students[3])
# Out:
# Sreeja

# %%
students[3]='Meghana'
print(students)
# Out:
# ['Anil', 'Simran', 'Pallavi', 'Meghana', 'Keerthi', 'Rafi', 'Salini', 'Adil']

# %%
#req: I want to delete Anil name from the list...?

# %%
del students[0]
print(students)
# Out:
# ['Simran', 'Pallavi', 'Meghana', 'Keerthi', 'Rafi', 'Salini', 'Adil']
