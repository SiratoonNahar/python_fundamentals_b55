# %%
students=['sunil','ruksana','keerthi','naveen','meghana','sumalatha']
print(students)
# Out:
# ['sunil', 'ruksana', 'keerthi', 'naveen', 'meghana', 'sumalatha']

# %%
#req: I want to aprreciate all the students above?

# %%
print(f"keep up the good work,{students[0].title()}")
# Out:
# keep up the good work,Sunil

# %%
print(f"keep up good work,{students[1].title()}")
# Out:
# keep up good work,Ruksana

# %%
print(f"keep up good work,{students[2].title()}")
# Out:
# keep up good work,Keerthi

# %%
for x in students:
    print(f"keep up the good work,{x.title()}")
# Out:
# keep up the good work,Sunil
# keep up the good work,Ruksana
# keep up the good work,Keerthi
# keep up the good work,Naveen
# keep up the good work,Meghana
# keep up the good work,Sumalatha

# %%
for a in students:
    print(a)
# Out:
# sunil
# ruksana
# keerthi
# naveen
# meghana
# sumalatha

# %%
for ironman in students:
    print(f"keep up the good work,{ironman.title()}")
# Out:
# keep up the good work,Sunil
# keep up the good work,Ruksana
# keep up the good work,Keerthi
# keep up the good work,Naveen
# keep up the good work,Meghana
# keep up the good work,Sumalatha

# %%
#req: I also want to tell them that "I will be looking for todays github url in my inbox"

# %%
for x in students:
    print(f"keep up the good work,{x.title()}")
    print(f"I will be looking forword to receive your Github URLs to my inbox,{x.title()}")
# Out:
# keep up the good work,Sunil
# I will be looking forword to receive your Github URLs to my inbox,Sunil
# keep up the good work,Ruksana
# I will be looking forword to receive your Github URLs to my inbox,Ruksana
# keep up the good work,Keerthi
# I will be looking forword to receive your Github URLs to my inbox,Keerthi
# keep up the good work,Naveen
# I will be looking forword to receive your Github URLs to my inbox,Naveen
# keep up the good work,Meghana
# I will be looking forword to receive your Github URLs to my inbox,Meghana
# keep up the good work,Sumalatha
# I will be looking forword to receive your Github URLs to my inbox,Sumalatha

# %%
for x in students:
    print(f"keep up the good work,{x.title()}")
    print(f"I will be looking forword to receive your Github URLs to my inbox,{x.title()}\n")
# Out:
# keep up the good work,Sunil
# I will be looking forword to receive your Github URLs to my inbox,Sunil
#
# keep up the good work,Ruksana
# I will be looking forword to receive your Github URLs to my inbox,Ruksana
#
# keep up the good work,Keerthi
# I will be looking forword to receive your Github URLs to my inbox,Keerthi
#
# keep up the good work,Naveen
# I will be looking forword to receive your Github URLs to my inbox,Naveen
#
# keep up the good work,Meghana
# I will be looking forword to receive your Github URLs to my inbox,Meghana
#
# keep up the good work,Sumalatha
# I will be looking forword to receive your Github URLs to my inbox,Sumalatha

# %%
for x in students:
    print(f"keep up the good work,{x.title()}")
    print(f"I will be looking forword to receive your Github URLs to my inbox,{x.title()}\n")
print("Thank You all for joining the session")
# Out:
# keep up the good work,Sunil
# I will be looking forword to receive your Github URLs to my inbox,Sunil
#
# keep up the good work,Ruksana
# I will be looking forword to receive your Github URLs to my inbox,Ruksana
#
# keep up the good work,Keerthi
# I will be looking forword to receive your Github URLs to my inbox,Keerthi
#
# keep up the good work,Naveen
# I will be looking forword to receive your Github URLs to my inbox,Naveen
#
# keep up the good work,Meghana
# I will be looking forword to receive your Github URLs to my inbox,Meghana
#
# keep up the good work,Sumalatha
# I will be looking forword to receive your Github URLs to my inbox,Sumalatha
#
# Thank You all for joining the session
