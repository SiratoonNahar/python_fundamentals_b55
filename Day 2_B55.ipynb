# %%
x=5
y=3

# %%
x+y
# Out:
# 8

# %%
first name= 'Siratoon'
print(first name)
# Out:
#   File "<ipython-input-7-d769374ec205>", line 1
#     first name= 'Siratoon'
#           ^
# SyntaxError: invalid syntax

# %%
firstname= 'Siratoon'
print(firstname)
# Out:
# Siratoon

# %%
1name='Kumar'
print(1name)
# Out:
#   File "<ipython-input-9-dbca9f9bbe45>", line 1
#     1name='Kumar'
#      ^
# SyntaxError: invalid syntax

# %%
name1='Kumar'
print(name1)
# Out:
# Kumar

# %%
name@='Vivek'
print(name@)
# Out:
#   File "<ipython-input-11-ff41ed971379>", line 2
#     print(name@)
#                ^
# SyntaxError: invalid syntax

# %%
name$='apple'
print(name$)
# Out:
#   File "<ipython-input-12-fcce883461ad>", line 1
#     name$='apple'
#         ^
# SyntaxError: invalid syntax

# %%
# this is a code

# %%
name= 'Varsha' # Single Quote
print(name)
# Out:
# Varsha

# %%
name="Naveen" # Double Quote
print(name)
# Out:
# Naveen

# %%
name="""Kamran""" # Triple Quote
print(name)
# Out:
# Kamran
